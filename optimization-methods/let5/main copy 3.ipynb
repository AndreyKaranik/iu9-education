# %%
using Random, Plots

function fitness(x)
    return 5 - 24x + 17x^2 - (11/3)x^3 + (1/4)x^4
end

function generate_population(size, bit_length)
    return [rand(0:(2^bit_length - 1)) for _ in 1:size]
end

function to_binary(x, bit_length)
    return lpad(string(x, base=2), bit_length, '0')
end

function crossover(parent1, parent2, crossover_point)
    bin1, bin2 = to_binary(parent1, 8), to_binary(parent2, 8)
    child1 = parse(Int, bin1[1:crossover_point] * bin2[crossover_point+1:end], base=2)
    child2 = parse(Int, bin2[1:crossover_point] * bin1[crossover_point+1:end], base=2)
    return child1, child2
end

function mutate(individual, mutation_rate, bit_length)
    bin_repr = to_binary(individual, bit_length)
    if rand() < mutation_rate
        mutation_point = rand(1:bit_length)
        new_bin = bin_repr[1:mutation_point-1] * (bin_repr[mutation_point] == '0' ? "1" : "0") * bin_repr[mutation_point+1:end]
        return parse(Int, new_bin, base=2)
    end
    return individual
end

function print_population(population, bit_length)
    println("ID | Десятичное | Двоичное  | Приспособленность")
    println("---|------------|-----------|------------------")
    for (i, x) in enumerate(population)
        println("$(i)  | $(x)        | $(to_binary(x, bit_length)) | $(fitness(x))")
    end
end

function visualize_generations(history, filename)
    x_vals = 0:0.1:10
    y_vals = fitness.(x_vals)
    anim = @animate for population in history
        plot(x_vals, y_vals, label="f(x)", lw=2)
        scatter!(population, fitness.(population), label="Популяция", color=:red)
    end
    Plots.gif(anim, filename, fps=2)
end

function genetic_algorithm(iterations, pop_size, bit_length, mutation_rate)
    population = generate_population(pop_size, bit_length)
    println("Начальная популяция:")
    print_population(population, bit_length)
    
    history = [copy(population)]
    for gen in 1:iterations
        sorted_population = sort(population, by=fitness)
        new_population = []
        for i in 1:2:(pop_size-1)
            p1, p2 = sorted_population[rand(1:pop_size)], sorted_population[rand(1:pop_size)]
            child1, child2 = crossover(p1, p2, rand(1:bit_length-1))
            push!(new_population, mutate(child1, mutation_rate, bit_length))
            push!(new_population, mutate(child2, mutation_rate, bit_length))
        end
        population = new_population
        push!(history, copy(population))
        println("\nПоколение $(gen):")
        print_population(population, bit_length)
    end
    
    visualize_generations(history, "genetic_algorithm.gif")
    return sort(population, by=fitness)[1]
end

bit_length = 4
best_solution = genetic_algorithm(100, 10, bit_length, 0.3)
println("\nЛучшее найденное решение: x = $best_solution, f(x) = $(fitness(best_solution))")
# Out:
# Начальная популяция:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 2        | 0010 | -0.33333333333333215
# 2  | 13        | 1101 | 1650.583333333334
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 7        | 0111 | 12.583333333333485
# 5  | 6        | 0110 | 5.0
# 6  | 5        | 0101 | 7.916666666666686
# 7  | 11        | 1011 | 577.916666666667
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 1:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 13        | 1101 | 1650.583333333334
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 13        | 1101 | 1650.583333333334
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 13        | 1101 | 1650.583333333334
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 9        | 1001 | 133.25
# 9  | 9        | 1001 | 133.25
# 10  | 5        | 0101 | 7.916666666666686
#
# Поколение 2:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 9        | 1001 | 133.25
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 9        | 1001 | 133.25
# 5  | 1        | 0001 | -5.416666666666666
# 6  | 6        | 0110 | 5.0
# 7  | 9        | 1001 | 133.25
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 5        | 0101 | 7.916666666666686
# 10  | 9        | 1001 | 133.25
#
# Поколение 3:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 9        | 1001 | 133.25
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 13        | 1101 | 1650.583333333334
# 5  | 9        | 1001 | 133.25
# 6  | 6        | 0110 | 5.0
# 7  | 3        | 0011 | 7.25
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 6        | 0110 | 5.0
#
# Поколение 4:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 3        | 0011 | 7.25
# 2  | 9        | 1001 | 133.25
# 3  | 9        | 1001 | 133.25
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 6        | 0110 | 5.0
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 13        | 1101 | 1650.583333333334
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 6        | 0110 | 5.0
#
# Поколение 5:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 2        | 0010 | -0.33333333333333215
# 2  | 6        | 0110 | 5.0
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 8        | 1000 | 47.66666666666674
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 6        | 0110 | 5.0
# 7  | 3        | 0011 | 7.25
# 8  | 6        | 0110 | 5.0
# 9  | 9        | 1001 | 133.25
# 10  | 13        | 1101 | 1650.583333333334
#
# Поколение 6:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 6        | 0110 | 5.0
# 3  | 6        | 0110 | 5.0
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 9        | 1001 | 133.25
# 8  | 6        | 0110 | 5.0
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 3        | 0011 | 7.25
#
# Поколение 7:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 3        | 0011 | 7.25
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 2        | 0010 | -0.33333333333333215
# 7  | 8        | 1000 | 47.66666666666674
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 6        | 0110 | 5.0
#
# Поколение 8:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 12        | 1100 | 1013.0
# 4  | 6        | 0110 | 5.0
# 5  | 8        | 1000 | 47.66666666666674
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 11        | 1011 | 577.916666666667
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 9:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 9        | 1001 | 133.25
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 6        | 0110 | 5.0
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 10:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 9        | 1001 | 133.25
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 7        | 0111 | 12.583333333333485
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 11:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 9        | 1001 | 133.25
# 2  | 12        | 1100 | 1013.0
# 3  | 0        | 0000 | 5.0
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 8        | 1000 | 47.66666666666674
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 6        | 0110 | 5.0
#
# Поколение 12:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 12        | 1100 | 1013.0
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 6        | 0110 | 5.0
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 0        | 0000 | 5.0
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 0        | 0000 | 5.0
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 13:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 12        | 1100 | 1013.0
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 12        | 1100 | 1013.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 6        | 0110 | 5.0
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 7        | 0111 | 12.583333333333485
# 10  | 9        | 1001 | 133.25
#
# Поколение 14:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 6        | 0110 | 5.0
# 5  | 4        | 0100 | 10.333333333333343
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 8        | 1000 | 47.66666666666674
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 5        | 0101 | 7.916666666666686
#
# Поколение 15:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 5        | 0101 | 7.916666666666686
# 2  | 6        | 0110 | 5.0
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 6        | 0110 | 5.0
# 5  | 15        | 1111 | 3751.25
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 6        | 0110 | 5.0
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 4        | 0100 | 10.333333333333343
#
# Поколение 16:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 6        | 0110 | 5.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 6        | 0110 | 5.0
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 5        | 0101 | 7.916666666666686
# 9  | 5        | 0101 | 7.916666666666686
# 10  | 4        | 0100 | 10.333333333333343
#
# Поколение 17:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 4        | 0100 | 10.333333333333343
# 4  | 5        | 0101 | 7.916666666666686
# 5  | 12        | 1100 | 1013.0
# 6  | 6        | 0110 | 5.0
# 7  | 6        | 0110 | 5.0
# 8  | 4        | 0100 | 10.333333333333343
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 5        | 0101 | 7.916666666666686
#
# Поколение 18:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 0        | 0000 | 5.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 4        | 0100 | 10.333333333333343
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 6        | 0110 | 5.0
# 8  | 3        | 0011 | 7.25
# 9  | 12        | 1100 | 1013.0
# 10  | 3        | 0011 | 7.25
#
# Поколение 19:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 6        | 0110 | 5.0
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 3        | 0011 | 7.25
# 6  | 6        | 0110 | 5.0
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 6        | 0110 | 5.0
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 6        | 0110 | 5.0
#
# Поколение 20:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 3        | 0011 | 7.25
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 6        | 0110 | 5.0
# 7  | 7        | 0111 | 12.583333333333485
# 8  | 4        | 0100 | 10.333333333333343
# 9  | 6        | 0110 | 5.0
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 21:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 3        | 0011 | 7.25
# 5  | 9        | 1001 | 133.25
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 1        | 0001 | -5.416666666666666
# 9  | 0        | 0000 | 5.0
# 10  | 4        | 0100 | 10.333333333333343
#
# Поколение 22:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 9        | 1001 | 133.25
# 5  | 4        | 0100 | 10.333333333333343
# 6  | 12        | 1100 | 1013.0
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 0        | 0000 | 5.0
# 9  | 11        | 1011 | 577.916666666667
# 10  | 0        | 0000 | 5.0
#
# Поколение 23:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 0        | 0000 | 5.0
# 2  | 12        | 1100 | 1013.0
# 3  | 0        | 0000 | 5.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 6        | 0110 | 5.0
# 6  | 6        | 0110 | 5.0
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 4        | 0100 | 10.333333333333343
#
# Поколение 24:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 4        | 0100 | 10.333333333333343
# 4  | 7        | 0111 | 12.583333333333485
# 5  | 4        | 0100 | 10.333333333333343
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 0        | 0000 | 5.0
# 8  | 6        | 0110 | 5.0
# 9  | 0        | 0000 | 5.0
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 25:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 5        | 0101 | 7.916666666666686
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 0        | 0000 | 5.0
# 6  | 6        | 0110 | 5.0
# 7  | 0        | 0000 | 5.0
# 8  | 12        | 1100 | 1013.0
# 9  | 6        | 0110 | 5.0
# 10  | 0        | 0000 | 5.0
#
# Поколение 26:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 13        | 1101 | 1650.583333333334
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 12        | 1100 | 1013.0
# 7  | 7        | 0111 | 12.583333333333485
# 8  | 6        | 0110 | 5.0
# 9  | 12        | 1100 | 1013.0
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 27:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 5        | 0101 | 7.916666666666686
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 13        | 1101 | 1650.583333333334
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 12        | 1100 | 1013.0
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 6        | 0110 | 5.0
# 10  | 2        | 0010 | -0.33333333333333215
#
# Поколение 28:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 5        | 0101 | 7.916666666666686
# 5  | 13        | 1101 | 1650.583333333334
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 6        | 0110 | 5.0
#
# Поколение 29:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 2        | 0010 | -0.33333333333333215
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 13        | 1101 | 1650.583333333334
# 5  | 11        | 1011 | 577.916666666667
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 12        | 1100 | 1013.0
# 8  | 6        | 0110 | 5.0
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 2        | 0010 | -0.33333333333333215
#
# Поколение 30:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 9        | 1001 | 133.25
# 4  | 6        | 0110 | 5.0
# 5  | 6        | 0110 | 5.0
# 6  | 9        | 1001 | 133.25
# 7  | 2        | 0010 | -0.33333333333333215
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 31:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 3        | 0011 | 7.25
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 12        | 1100 | 1013.0
# 6  | 9        | 1001 | 133.25
# 7  | 9        | 1001 | 133.25
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 6        | 0110 | 5.0
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 32:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 2        | 0010 | -0.33333333333333215
# 2  | 4        | 0100 | 10.333333333333343
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 9        | 1001 | 133.25
# 5  | 1        | 0001 | -5.416666666666666
# 6  | 3        | 0011 | 7.25
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 9        | 1001 | 133.25
# 10  | 3        | 0011 | 7.25
#
# Поколение 33:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 3        | 0011 | 7.25
# 3  | 3        | 0011 | 7.25
# 4  | 11        | 1011 | 577.916666666667
# 5  | 1        | 0001 | -5.416666666666666
# 6  | 6        | 0110 | 5.0
# 7  | 3        | 0011 | 7.25
# 8  | 1        | 0001 | -5.416666666666666
# 9  | 6        | 0110 | 5.0
# 10  | 6        | 0110 | 5.0
#
# Поколение 34:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 6        | 0110 | 5.0
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 3        | 0011 | 7.25
# 5  | 7        | 0111 | 12.583333333333485
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 9        | 1001 | 133.25
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 35:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 9        | 1001 | 133.25
# 2  | 9        | 1001 | 133.25
# 3  | 3        | 0011 | 7.25
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 4        | 0100 | 10.333333333333343
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 12        | 1100 | 1013.0
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 36:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 12        | 1100 | 1013.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 12        | 1100 | 1013.0
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 1        | 0001 | -5.416666666666666
# 9  | 12        | 1100 | 1013.0
# 10  | 6        | 0110 | 5.0
#
# Поколение 37:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 9        | 1001 | 133.25
# 3  | 12        | 1100 | 1013.0
# 4  | 12        | 1100 | 1013.0
# 5  | 8        | 1000 | 47.66666666666674
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 6        | 0110 | 5.0
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 3        | 0011 | 7.25
# 10  | 12        | 1100 | 1013.0
#
# Поколение 38:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 9        | 1001 | 133.25
# 3  | 11        | 1011 | 577.916666666667
# 4  | 9        | 1001 | 133.25
# 5  | 12        | 1100 | 1013.0
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 12        | 1100 | 1013.0
# 8  | 9        | 1001 | 133.25
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 39:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 9        | 1001 | 133.25
# 2  | 11        | 1011 | 577.916666666667
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 0        | 0000 | 5.0
# 5  | 9        | 1001 | 133.25
# 6  | 12        | 1100 | 1013.0
# 7  | 8        | 1000 | 47.66666666666674
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 12        | 1100 | 1013.0
#
# Поколение 40:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 12        | 1100 | 1013.0
# 2  | 0        | 0000 | 5.0
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 9        | 1001 | 133.25
# 6  | 12        | 1100 | 1013.0
# 7  | 1        | 0001 | -5.416666666666666
# 8  | 12        | 1100 | 1013.0
# 9  | 11        | 1011 | 577.916666666667
# 10  | 9        | 1001 | 133.25
#
# Поколение 41:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 12        | 1100 | 1013.0
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 1        | 0001 | -5.416666666666666
# 6  | 2        | 0010 | -0.33333333333333215
# 7  | 11        | 1011 | 577.916666666667
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 3        | 0011 | 7.25
#
# Поколение 42:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 11        | 1011 | 577.916666666667
# 6  | 12        | 1100 | 1013.0
# 7  | 3        | 0011 | 7.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 12        | 1100 | 1013.0
#
# Поколение 43:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 11        | 1011 | 577.916666666667
# 3  | 12        | 1100 | 1013.0
# 4  | 8        | 1000 | 47.66666666666674
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 11        | 1011 | 577.916666666667
# 7  | 11        | 1011 | 577.916666666667
# 8  | 3        | 0011 | 7.25
# 9  | 3        | 0011 | 7.25
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 44:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 7        | 0111 | 12.583333333333485
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 11        | 1011 | 577.916666666667
# 5  | 11        | 1011 | 577.916666666667
# 6  | 11        | 1011 | 577.916666666667
# 7  | 3        | 0011 | 7.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 11        | 1011 | 577.916666666667
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 45:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 15        | 1111 | 3751.25
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 15        | 1111 | 3751.25
# 5  | 15        | 1111 | 3751.25
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 9        | 1001 | 133.25
# 9  | 11        | 1011 | 577.916666666667
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 46:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 13        | 1101 | 1650.583333333334
# 2  | 15        | 1111 | 3751.25
# 3  | 3        | 0011 | 7.25
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 15        | 1111 | 3751.25
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 15        | 1111 | 3751.25
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 15        | 1111 | 3751.25
#
# Поколение 47:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 15        | 1111 | 3751.25
# 4  | 15        | 1111 | 3751.25
# 5  | 7        | 0111 | 12.583333333333485
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 15        | 1111 | 3751.25
# 10  | 15        | 1111 | 3751.25
#
# Поколение 48:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 15        | 1111 | 3751.25
# 6  | 15        | 1111 | 3751.25
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 13        | 1101 | 1650.583333333334
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 49:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 13        | 1101 | 1650.583333333334
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 15        | 1111 | 3751.25
# 5  | 11        | 1011 | 577.916666666667
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 5        | 0101 | 7.916666666666686
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 15        | 1111 | 3751.25
#
# Поколение 50:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 5        | 0101 | 7.916666666666686
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 13        | 1101 | 1650.583333333334
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 15        | 1111 | 3751.25
#
# Поколение 51:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 11        | 1011 | 577.916666666667
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 8        | 1000 | 47.66666666666674
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 11        | 1011 | 577.916666666667
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 52:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 11        | 1011 | 577.916666666667
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 11        | 1011 | 577.916666666667
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 11        | 1011 | 577.916666666667
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 53:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 9        | 1001 | 133.25
# 3  | 3        | 0011 | 7.25
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 11        | 1011 | 577.916666666667
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 3        | 0011 | 7.25
#
# Поколение 54:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 11        | 1011 | 577.916666666667
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 8        | 1000 | 47.66666666666674
# 8  | 9        | 1001 | 133.25
# 9  | 13        | 1101 | 1650.583333333334
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 55:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 3        | 0011 | 7.25
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 11        | 1011 | 577.916666666667
# 8  | 11        | 1011 | 577.916666666667
# 9  | 9        | 1001 | 133.25
# 10  | 0        | 0000 | 5.0
#
# Поколение 56:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 9        | 1001 | 133.25
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 11        | 1011 | 577.916666666667
# 5  | 9        | 1001 | 133.25
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 1        | 0001 | -5.416666666666666
# 8  | 9        | 1001 | 133.25
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 57:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 12        | 1100 | 1013.0
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 8        | 1000 | 47.66666666666674
# 5  | 11        | 1011 | 577.916666666667
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 9        | 1001 | 133.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 58:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 0        | 0000 | 5.0
# 2  | 9        | 1001 | 133.25
# 3  | 11        | 1011 | 577.916666666667
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 11        | 1011 | 577.916666666667
# 9  | 15        | 1111 | 3751.25
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 59:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 0        | 0000 | 5.0
# 2  | 0        | 0000 | 5.0
# 3  | 12        | 1100 | 1013.0
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 8        | 1000 | 47.66666666666674
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 11        | 1011 | 577.916666666667
# 9  | 8        | 1000 | 47.66666666666674
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 60:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 12        | 1100 | 1013.0
# 2  | 13        | 1101 | 1650.583333333334
# 3  | 8        | 1000 | 47.66666666666674
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 8        | 1000 | 47.66666666666674
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 8        | 1000 | 47.66666666666674
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 61:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 0        | 0000 | 5.0
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 0        | 0000 | 5.0
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 11        | 1011 | 577.916666666667
# 10  | 12        | 1100 | 1013.0
#
# Поколение 62:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 0        | 0000 | 5.0
# 3  | 0        | 0000 | 5.0
# 4  | 12        | 1100 | 1013.0
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 11        | 1011 | 577.916666666667
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 9        | 1001 | 133.25
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 63:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 12        | 1100 | 1013.0
# 3  | 11        | 1011 | 577.916666666667
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 9        | 1001 | 133.25
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 0        | 0000 | 5.0
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 0        | 0000 | 5.0
#
# Поколение 64:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 0        | 0000 | 5.0
# 3  | 15        | 1111 | 3751.25
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 9        | 1001 | 133.25
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 9        | 1001 | 133.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 6        | 0110 | 5.0
#
# Поколение 65:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 15        | 1111 | 3751.25
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 9        | 1001 | 133.25
# 5  | 0        | 0000 | 5.0
# 6  | 6        | 0110 | 5.0
# 7  | 15        | 1111 | 3751.25
# 8  | 15        | 1111 | 3751.25
# 9  | 15        | 1111 | 3751.25
# 10  | 15        | 1111 | 3751.25
#
# Поколение 66:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 15        | 1111 | 3751.25
# 3  | 0        | 0000 | 5.0
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 11        | 1011 | 577.916666666667
# 7  | 11        | 1011 | 577.916666666667
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 11        | 1011 | 577.916666666667
# 10  | 9        | 1001 | 133.25
#
# Поколение 67:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 0        | 0000 | 5.0
# 4  | 15        | 1111 | 3751.25
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 3        | 0011 | 7.25
# 7  | 0        | 0000 | 5.0
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 68:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 15        | 1111 | 3751.25
# 3  | 6        | 0110 | 5.0
# 4  | 15        | 1111 | 3751.25
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 0        | 0000 | 5.0
# 7  | 2        | 0010 | -0.33333333333333215
# 8  | 3        | 0011 | 7.25
# 9  | 11        | 1011 | 577.916666666667
# 10  | 7        | 0111 | 12.583333333333485
#
# Поколение 69:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 0        | 0000 | 5.0
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 11        | 1011 | 577.916666666667
# 4  | 11        | 1011 | 577.916666666667
# 5  | 6        | 0110 | 5.0
# 6  | 11        | 1011 | 577.916666666667
# 7  | 6        | 0110 | 5.0
# 8  | 15        | 1111 | 3751.25
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 2        | 0010 | -0.33333333333333215
#
# Поколение 70:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 10        | 1010 | 298.3333333333335
# 3  | 11        | 1011 | 577.916666666667
# 4  | 0        | 0000 | 5.0
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 6        | 0110 | 5.0
# 7  | 3        | 0011 | 7.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 11        | 1011 | 577.916666666667
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 71:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 3        | 0011 | 7.25
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 11        | 1011 | 577.916666666667
# 5  | 3        | 0011 | 7.25
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 3        | 0011 | 7.25
# 8  | 4        | 0100 | 10.333333333333343
# 9  | 11        | 1011 | 577.916666666667
# 10  | 6        | 0110 | 5.0
#
# Поколение 72:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 6        | 0110 | 5.0
# 3  | 3        | 0011 | 7.25
# 4  | 11        | 1011 | 577.916666666667
# 5  | 3        | 0011 | 7.25
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 3        | 0011 | 7.25
# 8  | 3        | 0011 | 7.25
# 9  | 3        | 0011 | 7.25
# 10  | 7        | 0111 | 12.583333333333485
#
# Поколение 73:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 3        | 0011 | 7.25
# 3  | 3        | 0011 | 7.25
# 4  | 7        | 0111 | 12.583333333333485
# 5  | 11        | 1011 | 577.916666666667
# 6  | 3        | 0011 | 7.25
# 7  | 3        | 0011 | 7.25
# 8  | 6        | 0110 | 5.0
# 9  | 7        | 0111 | 12.583333333333485
# 10  | 3        | 0011 | 7.25
#
# Поколение 74:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 5        | 0101 | 7.916666666666686
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 15        | 1111 | 3751.25
# 4  | 15        | 1111 | 3751.25
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 3        | 0011 | 7.25
# 7  | 3        | 0011 | 7.25
# 8  | 1        | 0001 | -5.416666666666666
# 9  | 3        | 0011 | 7.25
# 10  | 7        | 0111 | 12.583333333333485
#
# Поколение 75:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 3        | 0011 | 7.25
# 5  | 3        | 0011 | 7.25
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 3        | 0011 | 7.25
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 3        | 0011 | 7.25
# 10  | 3        | 0011 | 7.25
#
# Поколение 76:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 2        | 0010 | -0.33333333333333215
# 2  | 3        | 0011 | 7.25
# 3  | 3        | 0011 | 7.25
# 4  | 3        | 0011 | 7.25
# 5  | 11        | 1011 | 577.916666666667
# 6  | 3        | 0011 | 7.25
# 7  | 1        | 0001 | -5.416666666666666
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 2        | 0010 | -0.33333333333333215
# 10  | 5        | 0101 | 7.916666666666686
#
# Поколение 77:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 3        | 0011 | 7.25
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 7        | 0111 | 12.583333333333485
# 6  | 5        | 0101 | 7.916666666666686
# 7  | 3        | 0011 | 7.25
# 8  | 15        | 1111 | 3751.25
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 9        | 1001 | 133.25
#
# Поколение 78:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 3        | 0011 | 7.25
# 2  | 9        | 1001 | 133.25
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 9        | 1001 | 133.25
# 7  | 7        | 0111 | 12.583333333333485
# 8  | 15        | 1111 | 3751.25
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 7        | 0111 | 12.583333333333485
#
# Поколение 79:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 2        | 0010 | -0.33333333333333215
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 7        | 0111 | 12.583333333333485
# 5  | 3        | 0011 | 7.25
# 6  | 11        | 1011 | 577.916666666667
# 7  | 15        | 1111 | 3751.25
# 8  | 9        | 1001 | 133.25
# 9  | 0        | 0000 | 5.0
# 10  | 2        | 0010 | -0.33333333333333215
#
# Поколение 80:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 0        | 0000 | 5.0
# 3  | 5        | 0101 | 7.916666666666686
# 4  | 11        | 1011 | 577.916666666667
# 5  | 11        | 1011 | 577.916666666667
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 0        | 0000 | 5.0
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 0        | 0000 | 5.0
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 81:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 1        | 0001 | -5.416666666666666
# 3  | 5        | 0101 | 7.916666666666686
# 4  | 5        | 0101 | 7.916666666666686
# 5  | 11        | 1011 | 577.916666666667
# 6  | 11        | 1011 | 577.916666666667
# 7  | 2        | 0010 | -0.33333333333333215
# 8  | 1        | 0001 | -5.416666666666666
# 9  | 3        | 0011 | 7.25
# 10  | 0        | 0000 | 5.0
#
# Поколение 82:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 1        | 0001 | -5.416666666666666
# 2  | 3        | 0011 | 7.25
# 3  | 5        | 0101 | 7.916666666666686
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 3        | 0011 | 7.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 1        | 0001 | -5.416666666666666
# 10  | 3        | 0011 | 7.25
#
# Поколение 83:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 5        | 0101 | 7.916666666666686
# 2  | 1        | 0001 | -5.416666666666666
# 3  | 2        | 0010 | -0.33333333333333215
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 15        | 1111 | 3751.25
# 6  | 3        | 0011 | 7.25
# 7  | 5        | 0101 | 7.916666666666686
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 3        | 0011 | 7.25
# 10  | 2        | 0010 | -0.33333333333333215
#
# Поколение 84:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 3        | 0011 | 7.25
# 2  | 5        | 0101 | 7.916666666666686
# 3  | 3        | 0011 | 7.25
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 2        | 0010 | -0.33333333333333215
# 7  | 2        | 0010 | -0.33333333333333215
# 8  | 2        | 0010 | -0.33333333333333215
# 9  | 6        | 0110 | 5.0
# 10  | 1        | 0001 | -5.416666666666666
#
# Поколение 85:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 0        | 0000 | 5.0
# 2  | 6        | 0110 | 5.0
# 3  | 1        | 0001 | -5.416666666666666
# 4  | 2        | 0010 | -0.33333333333333215
# 5  | 2        | 0010 | -0.33333333333333215
# 6  | 1        | 0001 | -5.416666666666666
# 7  | 2        | 0010 | -0.33333333333333215
# 8  | 11        | 1011 | 577.916666666667
# 9  | 0        | 0000 | 5.0
# 10  | 10        | 1010 | 298.3333333333335
#
# Поколение 86:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 6        | 0110 | 5.0
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 11        | 1011 | 577.916666666667
# 5  | 11        | 1011 | 577.916666666667
# 6  | 0        | 0000 | 5.0
# 7  | 10        | 1010 | 298.3333333333335
# 8  | 6        | 0110 | 5.0
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 4        | 0100 | 10.333333333333343
#
# Поколение 87:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 6        | 0110 | 5.0
# 2  | 11        | 1011 | 577.916666666667
# 3  | 4        | 0100 | 10.333333333333343
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 6        | 0110 | 5.0
# 7  | 7        | 0111 | 12.583333333333485
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 14        | 1110 | 2543.666666666668
#
# Поколение 88:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 4        | 0100 | 10.333333333333343
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 14        | 1110 | 2543.666666666668
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 89:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 4        | 0100 | 10.333333333333343
# 2  | 7        | 0111 | 12.583333333333485
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 11        | 1011 | 577.916666666667
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 8        | 1000 | 47.66666666666674
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 8        | 1000 | 47.66666666666674
#
# Поколение 90:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 8        | 1000 | 47.66666666666674
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 7        | 0111 | 12.583333333333485
# 4  | 4        | 0100 | 10.333333333333343
# 5  | 11        | 1011 | 577.916666666667
# 6  | 9        | 1001 | 133.25
# 7  | 4        | 0100 | 10.333333333333343
# 8  | 6        | 0110 | 5.0
# 9  | 4        | 0100 | 10.333333333333343
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 91:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 5        | 0101 | 7.916666666666686
# 2  | 6        | 0110 | 5.0
# 3  | 13        | 1101 | 1650.583333333334
# 4  | 15        | 1111 | 3751.25
# 5  | 11        | 1011 | 577.916666666667
# 6  | 14        | 1110 | 2543.666666666668
# 7  | 3        | 0011 | 7.25
# 8  | 9        | 1001 | 133.25
# 9  | 9        | 1001 | 133.25
# 10  | 9        | 1001 | 133.25
#
# Поколение 92:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 9        | 1001 | 133.25
# 4  | 6        | 0110 | 5.0
# 5  | 15        | 1111 | 3751.25
# 6  | 9        | 1001 | 133.25
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 6        | 0110 | 5.0
# 9  | 9        | 1001 | 133.25
# 10  | 13        | 1101 | 1650.583333333334
#
# Поколение 93:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 15        | 1111 | 3751.25
# 3  | 11        | 1011 | 577.916666666667
# 4  | 9        | 1001 | 133.25
# 5  | 13        | 1101 | 1650.583333333334
# 6  | 9        | 1001 | 133.25
# 7  | 6        | 0110 | 5.0
# 8  | 9        | 1001 | 133.25
# 9  | 12        | 1100 | 1013.0
# 10  | 15        | 1111 | 3751.25
#
# Поколение 94:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 13        | 1101 | 1650.583333333334
# 2  | 11        | 1011 | 577.916666666667
# 3  | 11        | 1011 | 577.916666666667
# 4  | 11        | 1011 | 577.916666666667
# 5  | 15        | 1111 | 3751.25
# 6  | 9        | 1001 | 133.25
# 7  | 13        | 1101 | 1650.583333333334
# 8  | 14        | 1110 | 2543.666666666668
# 9  | 9        | 1001 | 133.25
# 10  | 9        | 1001 | 133.25
#
# Поколение 95:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 14        | 1110 | 2543.666666666668
# 2  | 11        | 1011 | 577.916666666667
# 3  | 11        | 1011 | 577.916666666667
# 4  | 9        | 1001 | 133.25
# 5  | 11        | 1011 | 577.916666666667
# 6  | 9        | 1001 | 133.25
# 7  | 15        | 1111 | 3751.25
# 8  | 11        | 1011 | 577.916666666667
# 9  | 9        | 1001 | 133.25
# 10  | 9        | 1001 | 133.25
#
# Поколение 96:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 15        | 1111 | 3751.25
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 9        | 1001 | 133.25
# 5  | 15        | 1111 | 3751.25
# 6  | 11        | 1011 | 577.916666666667
# 7  | 9        | 1001 | 133.25
# 8  | 9        | 1001 | 133.25
# 9  | 9        | 1001 | 133.25
# 10  | 15        | 1111 | 3751.25
#
# Поколение 97:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 11        | 1011 | 577.916666666667
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 8        | 1000 | 47.66666666666674
# 5  | 9        | 1001 | 133.25
# 6  | 9        | 1001 | 133.25
# 7  | 9        | 1001 | 133.25
# 8  | 15        | 1111 | 3751.25
# 9  | 10        | 1010 | 298.3333333333335
# 10  | 11        | 1011 | 577.916666666667
#
# Поколение 98:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 15        | 1111 | 3751.25
# 2  | 11        | 1011 | 577.916666666667
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 10        | 1010 | 298.3333333333335
# 5  | 15        | 1111 | 3751.25
# 6  | 9        | 1001 | 133.25
# 7  | 9        | 1001 | 133.25
# 8  | 10        | 1010 | 298.3333333333335
# 9  | 9        | 1001 | 133.25
# 10  | 9        | 1001 | 133.25
#
# Поколение 99:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 11        | 1011 | 577.916666666667
# 2  | 14        | 1110 | 2543.666666666668
# 3  | 10        | 1010 | 298.3333333333335
# 4  | 8        | 1000 | 47.66666666666674
# 5  | 10        | 1010 | 298.3333333333335
# 6  | 15        | 1111 | 3751.25
# 7  | 14        | 1110 | 2543.666666666668
# 8  | 15        | 1111 | 3751.25
# 9  | 9        | 1001 | 133.25
# 10  | 9        | 1001 | 133.25
#
# Поколение 100:
# ID | Десятичное | Двоичное  | Приспособленность
# ---|------------|-----------|------------------
# 1  | 10        | 1010 | 298.3333333333335
# 2  | 8        | 1000 | 47.66666666666674
# 3  | 14        | 1110 | 2543.666666666668
# 4  | 14        | 1110 | 2543.666666666668
# 5  | 14        | 1110 | 2543.666666666668
# 6  | 10        | 1010 | 298.3333333333335
# 7  | 15        | 1111 | 3751.25
# 8  | 9        | 1001 | 133.25
# 9  | 11        | 1011 | 577.916666666667
# 10  | 9        | 1001 | 133.25
#
# Лучшее найденное решение: x = 8, f(x) = 47.66666666666674
# ┌ Info: Saved animation to c:\Users\Golum\Desktop\iu9-education\optimization-methods\let5\genetic_algorithm.gif
# └ @ Plots C:\Users\Golum\.julia\packages\Plots\kLeqV\src\animation.jl:156
